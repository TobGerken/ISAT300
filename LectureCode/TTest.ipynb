# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.stats import t
plt.style.use('ggplot')

# %%
x = np.arange(55, 80, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, 67.3, 2.7))
plt.plot(x, norm.pdf(x, 70.1, 3.0))
plt.vlines(67.3,0,0.16,color = 'r', linestyle = ':')
plt.vlines(70.1,0,0.16,color = 'b', linestyle = ':')
plt.title('Comparison of Height Distributions')

ax.set_ylabel('Probability',fontsize = 12, fontweight='bold')
ax.set_xlabel('Height',fontsize = 12, fontweight='bold')
ax.legend(['1914 cohort', '1997 cohort'], fontsize = 12)
plt.savefig('StdHeight.jpg')

# %%
x = np.arange(55, 80, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)

plt.plot(67.3, 1, color = 'r')
plt.plot(70.1, 1.5, color = 'b')
 
x_error = 0.3
    
plt.errorbar(67.3, 1,
             xerr = x_error,
             fmt ='o')

plt.errorbar(70.1, 1.5,
             xerr = x_error,
             fmt ='o')


ax.set_ylim((0,4))
ax.set_xlim((60,75))
ax.set_yticks(np.array([])) 

plt.title('Comparison of Standard Erorr')

ax.set_xlabel('Height',fontsize = 12, fontweight='bold')
ax.legend(['1914 cohort', '1997 cohort'], fontsize = 12)

# %%
x = np.arange(65, 73, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, 67.3, 0.3))
plt.plot(x, norm.pdf(x, 70.1, 0.3))
plt.vlines(67.3,0,1.3,color = 'r', linestyle = ':')
plt.vlines(70.1,0,1.3,color = 'b', linestyle = ':')
plt.title('Comparison of Mean Heights (Standard Error)')

ax.set_ylabel('Probability',fontsize = 12, fontweight='bold')
ax.set_xlabel('Height',fontsize = 12, fontweight='bold')
ax.legend(['1914 cohort', '1997 cohort'], fontsize = 12)
plt.savefig('SdtError.jpg')

# %%
x = np.arange(55, 80, 0.1)
plt.plot(x, t.pdf(x,9), 'k', label="T-Distribution PDF")

# %%
placebo = np.random.normal(217.4,30.3,15)
newdrug = np.random.normal(195.9,28.7,15)

# %%
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)
plt.hist(placebo, alpha = 0.5)
plt.hist(newdrug, alpha = 0.5)

plt.vlines(217.4,0,4,color = 'r', linestyle = ':')
plt.vlines(195.9,0,4,color = 'b', linestyle = ':')

plt.legend(['Placebo', 'New Drug'])

ax.set_ylabel('Samples',fontsize = 12, fontweight='bold')
ax.set_xlabel('Cholesterol',fontsize = 12, fontweight='bold')
# Out:
# Text(0.5, 0, 'Cholesterol')

# %%
x = np.arange(-5, 5, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, 0, 1.5), linewidth = 3)
plt.plot(x, norm.pdf(x, 0, 1.5), linestyle=':', linewidth = 3)



ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Cholesterol Reduction',fontsize = 14, fontweight='bold')
ax.legend(['New Drug', 'Placebo'], fontsize = 14)
plt.savefig('CD1D2.jpg')

# %%
x = np.arange(-10, 10, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, -2, 1.5), linewidth = 3)
plt.plot(x, norm.pdf(x, 0, 1.5), linestyle='-', linewidth = 3)



ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Cholesterol Reduction',fontsize = 14, fontweight='bold')
ax.axvline(0, color = '#348ABD', linestyle = ':')
ax.axvline(-2, color = '#E24A33', linestyle = ':')
ax.legend(['New Drug', 'Placebo'], fontsize = 14)
plt.savefig('CD1D2_2.jpg')

# %%
x = np.arange(-10, 10, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, -4, 1.5), linewidth = 3)
plt.plot(x, norm.pdf(x, 0, 1.5), linestyle='-', linewidth = 3)



ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Cholesterol Reduction',fontsize = 14, fontweight='bold')
ax.axvline(0, color = '#348ABD')
ax.axvline(-4, color = '#E24A33')
ax.legend(['New Drug', 'Placebo'], fontsize = 14)
plt.savefig('CD1D2_3.jpg')

# %%
x = np.arange(-10, 10, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, -4, 1.5), linewidth = 3)
plt.plot(x, norm.pdf(x, 0, 3), linestyle='-', linewidth = 3)
ax.set_ylim((0,0.3))

ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Cholesterol Reduction',fontsize = 14, fontweight='bold')
ax.legend(['New Drug', 'Placebo'], fontsize = 14)
ax.axvline(0, color = '#348ABD')
ax.axvline(-4, color = '#E24A33')
plt.savefig('CD1D2_3.jpg')

# %%
x = np.arange(-10, 10, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

plt.plot(x, norm.pdf(x, -3, 3))
plt.plot(x, norm.pdf(x, 3, 3), linestyle='-', linewidth = 2)


plt.title('Comparison of Two Distributions')

ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Height',fontsize = 14, fontweight='bold')
ax.legend(['Distribution 1', 'Distribution 2'], fontsize = 14)
ax.set_ylim((0,0.3))
plt.savefig('CD1D2_3.jpg')

# %%
import matplotlib as mpl


cmap_use=plt.get_cmap('Blues',10)


x = np.arange(-10, 10, 0.1)
#plot normal distribution with mean 0 and standard deviation 1
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)

for i in np.arange(1.5, 3, 0.1):
    plt.plot(x, norm.pdf(x, 0, i), color = 'tab:blue')
    
plt.plot(x, norm.pdf(x, -4, 1.5), linestyle='-', linewidth = 3, color = 'tab:red')
ax.set_ylim((0,0.3))


ax.set_ylabel('Probability',fontsize = 14, fontweight='bold')
ax.set_xlabel('Cholesterol Reduction',fontsize = 14, fontweight='bold')
ax.axvline(0, color = '#348ABD')
ax.axvline(-4, color = '#E24A33')
ax.set_ylim((0,0.3))
plt.savefig('CD1D2_3.jpg')

# %%
import matplotlib as mpl

cmap_get=plt.get_cmap('Blues',10)
cmap_get(2)
# Out:
# (np.float64(0.7973856209150327),
#  np.float64(0.8727668845315903),
#  np.float64(0.9442265795206972),
#  np.float64(1.0))
