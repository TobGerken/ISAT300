# %% [markdown]
# ## Nothing to see here ...
#
# But this is how I create some plots for the lecture slides, feel free to browse around

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# 100 linearly spaced numbers
x = np.linspace(0,30,500)

# the function, which is y = sin(x) here
y = np.sin(x)+1

# setting the axes at the centre
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.set_ylabel('Measurand',fontsize = 12, fontweight='bold')
ax.set_xlabel('Time',fontsize = 12, fontweight='bold')
ax.set_ylim((0,4))

# plot the function
plt.plot(x,y, 'b-')

# show the plot

plt.savefig('zero_sin.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# 100 linearly spaced numbers
x = [0, 10, 10.01, 20]
y = [0, 0, 2, 2]
# the function, which is y = sin(x) here

# setting the axes at the centre
fig = plt.figure(figsize = (6, 5))
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.set_ylabel('Measurand',fontsize = 12, fontweight='bold')
ax.set_xlabel('Time',fontsize = 12, fontweight='bold')
ax.set_ylim((0,4))

# plot the function
plt.plot(x,y, 'b-')

# show the plot

plt.savefig('zero_step.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# 100 linearly spaced numbers
x = np.linspace(0,30,500)

# the function, which is y = sin(x) here
y = np.sin(x)+1

m = [0.5, 1 , 2]
c = ['r','k','g']
# setting the axes at the centre
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
# first Plot 

    ax[i].spines['right'].set_color('none')
    ax[i].spines['top'].set_color('none')
    ax[i].xaxis.set_ticks_position('bottom')
    ax[i].yaxis.set_ticks_position('left')
    ax[i].set_ylabel('Sensor Output',fontsize = 12, fontweight='bold')
    ax[i].set_xlabel('Time',fontsize = 12, fontweight='bold')

    # plot the function
    ax[i].plot(x,y*m[i],color = c[i])
    ax[i].set_ylim((0,4))

# show the plot

plt.savefig('zero_sin_r.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

x = [0, 10, 10.01, 20]
y = np.array([0, 0, 2, 2])

m = [0.5, 1 , 1.5]
c = ['r','k','g']
# setting the axes at the centre
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
# first Plot 

    ax[i].spines['right'].set_color('none')
    ax[i].spines['top'].set_color('none')
    ax[i].xaxis.set_ticks_position('bottom')
    ax[i].yaxis.set_ticks_position('left')
    ax[i].set_ylabel('Sensor Output',fontsize = 12, fontweight='bold')
    ax[i].set_xlabel('Time',fontsize = 12, fontweight='bold')

    # plot the function
    ax[i].plot(x,y*m[i],color = c[i])
    ax[i].set_ylim((0,4))

# show the plot
plt.savefig('zero_step_r.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams["mathtext.fontset"] = "cm"

t = np.linspace(2, 10, 500)
y = np.exp(-0.1*t*4)*np.sin(t*4)
y = y+1
t = np.append([0, 1.8], t)
y = np.append([0, 0], y)


plt.plot(t, y)


plt.xlabel("$t$", fontsize=14, loc="right")
plt.ylabel("$y(t)$", fontsize=14)
plt.yticks([-1, -0.5, 0, 0.5, 1])

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %%
np.exp(4*t)
# Out:
# array([2.98095799e+03, 3.17838427e+03, 3.38888593e+03, 3.61332894e+03,
#        3.85263661e+03, 4.10779342e+03, 4.37984905e+03, 4.66992269e+03,
#        4.97920766e+03, 5.30897630e+03, 5.66058524e+03, 6.03548094e+03,
#        6.43520565e+03, 6.86140380e+03, 7.31582867e+03, 7.80034972e+03,
#        8.31696018e+03, 8.86778531e+03, 9.45509111e+03, 1.00812937e+04,
#        1.07489691e+04, 1.14608641e+04, 1.22199073e+04, 1.30292212e+04,
#        1.38921353e+04, 1.48121995e+04, 1.57931988e+04, 1.68391688e+04,
#        1.79544124e+04, 1.91435178e+04, 2.04113765e+04, 2.17632044e+04,
#        2.32045627e+04, 2.47413810e+04, 2.63799814e+04, 2.81271049e+04,
#        2.99899389e+04, 3.19761468e+04, 3.40938995e+04, 3.63519092e+04,
#        3.87594649e+04, 4.13264710e+04, 4.40634876e+04, 4.69817746e+04,
#        5.00933371e+04, 5.34109758e+04, 5.69483388e+04, 6.07199784e+04,
#        6.47414104e+04, 6.90291784e+04, 7.36009215e+04, 7.84754473e+04,
# ...
